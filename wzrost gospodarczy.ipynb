# %%
using Plots
using Random
plotly()
# Out:
# Plots.PlotlyBackend()

# %% [markdown]
# # Matematyczne modelowanie rozwoju gospodarczego
# Wzrost gospodarczy to powiększanie się z okresu na okres podstawowych wielkości gospodarczych. Występuje gdy rośnie zakres świadczonych usług,<br>a spada produkcja rolnictwa i przemysłu.

# %% [markdown]
# # Model Solowa
# Neoklasyczny (inaczej: egzogeniczny, podażowy) model wzrostu gospodarczego oparty na następujących założeniach:
# 1. Nie istnieją trudności związane ze zbytem wytworzonej produkcji - w gospodarce istnieje nieograniczony popyt.<br><br>
# 2. Produkcję określa dwuczynnikowa funkcja produkcji o stałych efektach skali $Y = F(K,L)$, gdzie:<br>
# Y - produkcja,<br>
# K - nakład kapitału<br>
# L - nakład pracy <br><br>
# 3. Nie bierzemy pod uwagę rozwoju technologicznego.

# %% [markdown]
# ### Funkcja produkcji Cobb-Douglasa
# Jedna z funkcji wykorzystywana w modelu Solowa, o wzorze
#
# $Y = A K^\alpha L^\beta$.
#
#
# Parametry funkcji produkcji Cobba-Douglasa ($\alpha , \beta$) mają ważną interpretację ekonomiczną - są to współczynniki elastyczności produkcji względem kapitału i pracy. Przyjmują wartości z przedziału [0,1].<br><br>

# %% [markdown]
# ### Zastosowanie w modelu Solowa
# Z założenia modelu, funkcja ma stały efekt skali, tzn. $\alpha + \beta = 1$. Przekształcając wzór funkcji produkcji Cobb-Douglasa otrzymujemy<br><br>
# $Y = A K^\alpha L^\beta = A K^\alpha L^{1-\alpha}$.<br><br>
#
# Miarą dobrobytu danej gospodarki jest produkcja "per capita", dlatego dzielimy obustronnie przez L, aby uzyskać wielkość produkcji na jednostkę.<br><br>
# $\cfrac{Y}{L} = \cfrac{A K^\alpha L^{1-\alpha}}{L} = \cfrac{A K^\alpha}{L^{\alpha}}$

# %%
A = 3.5
K = 1200
L = 500
α = 0.7

plot(K -> A*(K/L)^α,K,800K,
    xlabel = "Kapitał",
    ylabel = "Produkcja na jednostkę",
    label = "Pierwsza gospodarka",
    color = :red,
    linewidth = 3,
    legend = :topleft)

A = 4

plot!(K -> A*(K/L)^α,K,800K,
    label = "Druga gospodarka",
    color = :blue,
    linewidth = 3)

A = 2

plot!(K -> A*(K/L)^α,K,800K,
    label = "Trzecia gospodarka",
    color = :green,
    linewidth = 3)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     </head>
#     <body>
#             <div id="616a76fd-3f66-4f71-ac65-a34033ba212e" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#     PLOT = document.getElementById('616a76fd-3f66-4f71-ac65-a34033ba212e');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             10563.46727617286,
#             97142.24258103587,
#             149172.47775983217,
#             193163.37942467618,
#             240949.8288676897,
#             285004.7084678015,
#             332236.19541454245,
#             386958.50493178476,
#             435589.23573924735,
#             478234.00427476293,
#             524728.2490411203,
#             571498.8218681962,
#             623209.6709242788,
#             672411.238986156,
#             723569.4538386828,
#             766633.7738157711,
#             819210.4273717259,
#             868634.0324410057,
#             947814.4804185983,
#             960000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Pierwsza gospodarka",
#         "zmin": null,
#         "legendgroup": "Pierwsza gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             6.459753018563344,
#             29.611034835078517,
#             139.9505884674845,
#             188.9605453722792,
#             226.43126754224613,
#             264.32465671105086,
#             297.29353547014193,
#             330.98011513296865,
#             368.25963537345126,
#             400.0764966605793,
#             427.10765797823166,
#             455.7672899892409,
#             483.83778235736924,
#             514.0826775129186,
#             542.1675443978804,
#             570.7227681188591,
#             594.2929864348014,
#             622.5380076482028,
#             648.5968420429248,
#             689.4382572081906,
#             695.630962909727
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             10563.46727617286,
#             97142.24258103587,
#             149172.47775983217,
#             193163.37942467618,
#             240949.8288676897,
#             285004.7084678015,
#             332236.19541454245,
#             386958.50493178476,
#             435589.23573924735,
#             478234.00427476293,
#             524728.2490411203,
#             571498.8218681962,
#             623209.6709242788,
#             672411.238986156,
#             723569.4538386828,
#             766633.7738157711,
#             819210.4273717259,
#             868634.0324410057,
#             947814.4804185983,
#             960000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Druga gospodarka",
#         "zmin": null,
#         "legendgroup": "Druga gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 0, 255, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             7.382574878358107,
#             33.84118266866116,
#             159.94352967712513,
#             215.9549089968905,
#             258.77859147685274,
#             302.0853219554867,
#             339.76404053730505,
#             378.26298872339277,
#             420.8681547125157,
#             457.23028189780496,
#             488.1230376894076,
#             520.8769028448468,
#             552.9574655512791,
#             587.5230600147642,
#             619.6200507404347,
#             652.254592135839,
#             679.1919844969159,
#             711.4720087408032,
#             741.2535337633426,
#             787.9294368093607,
#             795.0068147539737
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             10563.46727617286,
#             97142.24258103587,
#             149172.47775983217,
#             193163.37942467618,
#             240949.8288676897,
#             285004.7084678015,
#             332236.19541454245,
#             386958.50493178476,
#             435589.23573924735,
#             478234.00427476293,
#             524728.2490411203,
#             571498.8218681962,
#             623209.6709242788,
#             672411.238986156,
#             723569.4538386828,
#             766633.7738157711,
#             819210.4273717259,
#             868634.0324410057,
#             947814.4804185983,
#             960000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Trzecia gospodarka",
#         "zmin": null,
#         "legendgroup": "Trzecia gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 128, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             3.6912874391790536,
#             16.92059133433058,
#             79.97176483856256,
#             107.97745449844525,
#             129.38929573842637,
#             151.04266097774334,
#             169.88202026865252,
#             189.13149436169638,
#             210.43407735625786,
#             228.61514094890248,
#             244.0615188447038,
#             260.4384514224234,
#             276.47873277563957,
#             293.7615300073821,
#             309.8100253702174,
#             326.1272960679195,
#             339.59599224845795,
#             355.7360043704016,
#             370.6267668816713,
#             393.96471840468035,
#             397.50340737698684
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             200000.0,
#             400000.0,
#             600000.0,
#             800000.0
#         ],
#         "range": [
#             -27564.0,
#             988764.0
#         ],
#         "domain": [
#             0.07646908719743364,
#             0.9934383202099737
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0",
#             "2.0×10<sup>5</sup>",
#             "4.0×10<sup>5</sup>",
#             "6.0×10<sup>5</sup>",
#             "8.0×10<sup>5</sup>"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "Kapitał",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             200.0,
#             400.0,
#             600.0,
#             800.0
#         ],
#         "range": [
#             -20.048178380264783,
#             818.7462805734175
#         ],
#         "domain": [
#             0.07581474190726165,
#             0.9901574803149606
#         ],
#         "mirror": false,

# %%
A = 3.5

plot(K -> (A*((K+1)/L)^α)-(A*(K/L)^α), K, 100K,
    xlabel = "Kapitał",
    ylabel = "Przyrost produkcji na jednostkę",
    label = "Pierwsza gospodarka",
    color = :red,
    linewidth = 3,
    legend = :topright)

A = 4
plot!(K -> (A*((K+1)/L)^α)-(A*(K/L)^α), K, 100K,
    label = "Druga gospodarka",
    color = :blue,
    linewidth = 3)

A = 2
plot!(K -> (A*((K+1)/L)^α)-(A*(K/L)^α), K, 100K,
    label = "Trzecia gospodarka",
    color = :green,
    linewidth = 3)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     </head>
#     <body>
#             <div id="b3e3502a-96c9-4a3c-9638-0eb22dc18c1c" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#     PLOT = document.getElementById('b3e3502a-96c9-4a3c-9638-0eb22dc18c1c');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             1345.0224124438537,
#             1490.0448248877074,
#             1635.067237331561,
#             1780.089649775415,
#             1925.1120622192689,
#             2070.1344746631225,
#             2215.1568871069762,
#             2360.17929955083,
#             2695.4147014274504,
#             3030.6501033040713,
#             3365.885505180692,
#             3701.1209070573123,
#             4371.591710810553,
#             5042.062514563795,
#             5712.533318317037,
#             6383.004122070278,
#             7053.474925823519,
#             7723.945729576761,
#             9064.887337083244,
#             10405.828944589726,
#             11746.770552096208,
#             13087.712159602692,
#             14699.412185479048,
#             16311.112211355405,
#             17922.81223723176,
#             19534.512263108118,
#             22259.855983270543,
#             24985.19970343297,
#             30906.17403992651,
#             36364.78865871383,
#             42217.000433090994,
#             48997.36168741764,
#             55022.946605989346,
#             60306.841580978136,
#             66067.70545065195,
#             71862.80771583407,
#             78270.03431977922,
#             84366.34876048741,
#             90705.10128914844,
#             96040.9807356212,
#             102555.48474318006,
#             108679.31065289056,
#             118490.15464510792,
#             120000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Pierwsza gospodarka",
#         "zmin": null,
#         "legendgroup": "Pierwsza gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             0.0037677184071824854,
#             0.0036409926678233617,
#             0.0035308849940021148,
#             0.0034338914565772427,
#             0.003347479531710107,
#             0.0032697642707351093,
#             0.0031993079916006195,
#             0.003134991232691675,
#             0.0030759267222393305,
#             0.0029558013162240826,
#             0.0028536772245697506,
#             0.00276527245410918,
#             0.002687630122947482,
#             0.0025567031275581797,
#             0.002449580376765681,
#             0.00235953842651071,
#             0.002282282176022221,
#             0.002214914202792073,
#             0.002155395062075627,
#             0.0020543345581032213,
#             0.001971050795095408,
#             0.0019006668057812703,
#             0.0018400218637992793,
#             0.001777021405615642,
#             0.0017224158565056769,
#             0.0016744091946634398,
#             0.0016317099990885708,
#             0.00156901627985917,
#             0.00151558265558549,
#             0.0014219076795072283,
#             0.0013541942629018422,
#             0.0012949092296565823,
#             0.0012383230106536303,
#             0.001195976769764684,
#             0.0011635258218660738,
#             0.001132111828880511,
#             0.001103913184735461,
#             0.0010759884060291824,
#             0.0010520479464872778,
#             0.0010294300684847713,
#             0.0010119275670490424,
#             0.000992198985414916,
#             0.0009750848738008244,
#             0.0009501274199124055,
#             0.0009465251644087402
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             1345.0224124438537,
#             1490.0448248877074,
#             1635.067237331561,
#             1780.089649775415,
#             1925.1120622192689,
#             2070.1344746631225,
#             2215.1568871069762,
#             2360.17929955083,
#             2695.4147014274504,
#             3030.6501033040713,
#             3365.885505180692,
#             3701.1209070573123,
#             4371.591710810553,
#             5042.062514563795,
#             5712.533318317037,
#             6383.004122070278,
#             7053.474925823519,
#             7723.945729576761,
#             9064.887337083244,
#             10405.828944589726,
#             11746.770552096208,
#             13087.712159602692,
#             14699.412185479048,
#             16311.112211355405,
#             17922.81223723176,
#             19534.512263108118,
#             22259.855983270543,
#             24985.19970343297,
#             30906.17403992651,
#             36364.78865871383,
#             42217.000433090994,
#             48997.36168741764,
#             55022.946605989346,
#             60306.841580978136,
#             66067.70545065195,
#             71862.80771583407,
#             78270.03431977922,
#             84366.34876048741,
#             90705.10128914844,
#             96040.9807356212,
#             102555.48474318006,
#             108679.31065289056,
#             118490.15464510792,
#             120000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Druga gospodarka",
#         "zmin": null,
#         "legendgroup": "Druga gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 0, 255, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             0.00430596389392246,
#             0.00416113447751254,
#             0.004035297136002924,
#             0.003924447378945928,
#             0.003825690893382472,
#             0.0037368734522686964,
#             0.003656351990400708,
#             0.003582847123075439,
#             0.0035153448254163777,
#             0.0033780586471117147,
#             0.0032613453995082864,
#             0.003160311376126046,
#             0.0030715772833680433,
#             0.00292194643149557,
#             0.002799520430588842,
#             0.0026966153445862062,
#             0.0026083224868855837,
#             0.0025313305174741174,
#             0.0024633086423726525,
#             0.0023478109235490763,
#             0.002252629480111068,
#             0.0021721906351785947,
#             0.0021028821300603795,
#             0.0020308816064158464,
#             0.0019684752645758863,
#             0.0019136105081898336,
#             0.0018648114275308103,
#             0.0017931614627002546,
#             0.0017320944635343949,
#             0.0016250373480062308,
#             0.001547650586175564,
#             0.0014798962624666956,
#             0.0014152262978797125,
#             0.0013668305940086611,
#             0.00132974379641837,
#             0.0012938420901349446,
#             0.0012616150682731586,
#             0.0012297010354700433,
#             0.001202340510275235,
#             0.0011764915068397386,
#             0.0011564886480357472,
#             0.0011339416976170469,
#             0.001114382712898987,
#             0.0010858599084713205,
#             0.0010817430450345
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             1345.0224124438537,
#             1490.0448248877074,
#             1635.067237331561,
#             1780.089649775415,
#             1925.1120622192689,
#             2070.1344746631225,
#             2215.1568871069762,
#             2360.17929955083,
#             2695.4147014274504,
#             3030.6501033040713,
#             3365.885505180692,

# %% [markdown]
# <b>Obserwacje z wykresów:</b><br>
# * Im większy kapitał, tym mniejszy przyrost produkcji na jednostkę.
# * Przyrost produkcji każdej gospodarki jest najszybszy w początkowej fazie rozwoju.<br><br>
#
# <b>Wniosek z wykresów:</b><br>
# * Zakładając równy dostęp do technologii, kraje biedniejsze rozwijają się szybciej od bogatszych.<br><br>

# %% [markdown]
# ### Udoskonalenie modelu
# Przyjmijmy, że postęp techniczny ma charakter pracoefektywnościowy. Funkcja produkcji ma wtedy postać <br><br>
# $Y=K^\alpha (AL)^{1-\alpha}$. <br><br>
# Wyliczamy produkcję "per capita"<br><br>
# $\cfrac{Y}{L}=\cfrac{K^\alpha (AL)^{1-\alpha}}{L}$

# %%
A = 3
K = 1200
L = 50
α = 0.7

plot(K -> A*(K/L)^α,K,500K,
    xlabel = "Kapitał",
    ylabel = "Produkcja na jednostkę",
    label = "Pierwsza gospodarka",
    color = :red,
    linewidth = 3,
    legend = :topleft)

plot!(K -> (K/L)^α*(A*((K*0.001)^(1/4))^(1-α)),K,500K,
    label = "Druga gospodarka",
    color = :green,
    linewidth = 3)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     </head>
#     <body>
#             <div id="1eb5c1ed-6eef-4983-a5e2-394be5893015" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#     PLOT = document.getElementById('1eb5c1ed-6eef-4983-a5e2-394be5893015');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             7047.772429049133,
#             61118.87240042165,
#             93613.34968980758,
#             121087.01668700052,
#             150931.1196557912,
#             178444.74283533535,
#             207942.2547082061,
#             242118.01496991314,
#             272489.39753927966,
#             299122.36312028376,
#             328159.4446452053,
#             357369.1015171839,
#             389664.11237949325,
#             420392.00031801226,
#             452341.8741745967,
#             479236.8624957069,
#             512072.59481663484,
#             542939.1516746706,
#             592389.7693728167,
#             600000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Pierwsza gospodarka",
#         "zmin": null,
#         "legendgroup": "Pierwsza gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             27.75039210247872,
#             95.82494139909198,
#             434.67532242530825,
#             585.8395689076691,
#             701.4723501714051,
#             818.4410565435528,
#             920.2268103969116,
#             1024.2410454540616,
#             1139.3606729497515,
#             1237.6190277024484,
#             1321.102364621976,
#             1409.6188131677088,
#             1496.3188666729395,
#             1589.7379376845515,
#             1676.4876631971742,
#             1764.6923656031618,
#             1837.5002339338512,
#             1924.7499869419444,
#             2005.2478700156214,
#             2131.4126372849096,
#             2150.5429815771586
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             1200.0,
#             7047.772429049133,
#             61118.87240042165,
#             93613.34968980758,
#             121087.01668700052,
#             150931.1196557912,
#             178444.74283533535,
#             207942.2547082061,
#             242118.01496991314,
#             272489.39753927966,
#             299122.36312028376,
#             328159.4446452053,
#             357369.1015171839,
#             389664.11237949325,
#             420392.00031801226,
#             452341.8741745967,
#             479236.8624957069,
#             512072.59481663484,
#             542939.1516746706,
#             592389.7693728167,
#             600000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Druga gospodarka",
#         "zmin": null,
#         "legendgroup": "Druga gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 128, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             28.132460474686827,
#             110.93854170908868,
#             591.7361952027535,
#             823.434455423498,
#             1005.1777705499914,
#             1192.328203323531,
#             1357.5557198557317,
#             1528.4381948016937,
#             1719.7418413529876,
#             1884.6825019410016,
#             2025.9332682627394,
#             2176.747505428489,
#             2325.4549304812285,
#             2486.722472726822,
#             2637.3905465104312,
#             2791.4446207389096,
#             2919.2323914608123,
#             3073.0822941178344,
#             3215.6916704997034,
#             3440.4329837068735,
#             3474.637246134779
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             100000.0,
#             200000.0,
#             300000.0,
#             400000.0,
#             500000.0,
#             600000.0
#         ],
#         "range": [
#             -16764.0,
#             617964.0
#         ],
#         "domain": [
#             0.09128390201224845,
#             0.9934383202099738
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0",
#             "1.0×10<sup>5</sup>",
#             "2.0×10<sup>5</sup>",
#             "3.0×10<sup>5</sup>",
#             "4.0×10<sup>5</sup>",
#             "5.0×10<sup>5</sup>",
#             "6.0×10<sup>5</sup>"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "Kapitał",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             1000.0,
#             2000.0,
#             3000.0
#         ],
#         "range": [
#             -75.65621351849029,
#             3578.043851755748
#         ],
#         "domain": [
#             0.07581474190726165,
#             0.9901574803149606
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0",
#             "1000",
#             "2000",
#             "3000"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "Produkcja na jednostkę",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "top",
#         "xanchor": "left",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 0.07
#     },
#     "width": 600
# }
# );
#     });
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# ### Akumulacja kapitału
# Przyrost kapitału zadany jest wzorem $\Delta K=sY-\delta K$, gdzie: <br><br>
# s - stopa oszczędności <br>
# $\delta$ - stopa deprecjacji kapitału <br><br>
#
# Z powyższego równania można wyprowadzić fundamentalne równanie modelu Solowa postaci $\Delta k=sy-(d+n+g)k$. <br><br>

# %%
s = 0.7
k = K/L

plot(k -> (k)^α*(A*((k*L*0.00001)^(1/4))^(-α)),k,500k,
    xlabel = "Kapitał na jednostkę pracy efektywnej",
    ylabel = "Produkcja na jednostkę pracy efektywnej",
    label = "Gospodarka",
    color = :green,
    linewidth = 3,
    legend = :topleft)

plot!(k -> s*(k)^α*(A*((k*L*0.0003)^(1/4))^(-α)),k,500k,
    label = "",
    color = :green,
    linewidth = 3,
    legend = :topleft)

plot!(k -> k*(0.08),k,500k,
    label = "Deprecjacja",
    color = :red,
    linewidth = 2)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#
#     </head>
#     <body>
#             <div id="e5db73c9-233a-4994-a2b5-95eb7c422719" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#     PLOT = document.getElementById('e5db73c9-233a-4994-a2b5-95eb7c422719');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             24.0,
#             53.23886214524566,
#             82.47772429049132,
#             111.71658643573699,
#             140.95544858098265,
#             276.1331985094139,
#             411.3109484378452,
#             546.4886983662765,
#             681.6664482947077,
#             952.0219481515703,
#             1222.3774480084328,
#             1547.3222209022922,
#             1872.2669937961516,
#             2147.003663768081,
#             2421.74033374001,
#             3018.622393115824,
#             3568.894856706707,
#             4158.845094164123,
#             4842.360299398262,
#             5449.787950785592,
#             5982.447262405675,
#             6563.188892904106,
#             7147.382030343678,
#             7793.282247589865,
#             8407.840006360246,
#             9046.837483491934,
#             9584.737249914137,
#             10241.451896332697,
#             10858.783033493413,
#             11847.795387456334,
#             12000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Gospodarka",
#         "zmin": null,
#         "legendgroup": "Gospodarka",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 128, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             60.17448829512777,
#             91.42639708897461,
#             115.04778334776518,
#             134.91594322294006,
#             152.429661317269,
#             216.96455066421427,
#             267.4489490449571,
#             310.47856757295875,
#             348.6797782955205,
#             415.51925956875846,
#             473.78826707755854,
#             536.2056727231987,
#             592.6449513758843,
#             636.8156332081139,
#             678.3728853776731,
#             761.5547274819529,
#             831.5372798727335,
#             901.0776022961277,
#             976.0149761788505,
#             1038.4863590133532,
#             1090.593526134177,
#             1144.9508092941269,
#             1197.3708383857202,
#             1253.0105184950842,
#             1303.9496867963828,
#             1355.0718332635786,
#             1396.7899937796753,
#             1446.2431232558329,
#             1491.374148310061,
#             1561.2096075494533,
#             1571.707255942705
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             24.0,
#             53.23886214524566,
#             82.47772429049132,
#             111.71658643573699,
#             140.95544858098265,
#             276.1331985094139,
#             411.3109484378452,
#             546.4886983662765,
#             681.6664482947077,
#             952.0219481515703,
#             1222.3774480084328,
#             1547.3222209022922,
#             1872.2669937961516,
#             2147.003663768081,
#             2421.74033374001,
#             3018.622393115824,
#             3568.894856706707,
#             4158.845094164123,
#             4842.360299398262,
#             5449.787950785592,
#             5982.447262405675,
#             6563.188892904106,
#             7147.382030343678,
#             7793.282247589865,
#             8407.840006360246,
#             9046.837483491934,
#             9584.737249914137,
#             10241.451896332697,
#             10858.783033493413,
#             11847.795387456334,
#             12000.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 128, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 3
#         },
#         "y": [
#             23.228128840991793,
#             35.291768841220524,
#             44.409928695459705,
#             52.079294742255854,
#             58.83981588511401,
#             83.75111578911945,
#             103.23874490357926,
#             119.84873281481964,
#             134.59489301801975,
#             160.39579513895285,
#             182.88838381229465,
#             206.98230768825002,
#             228.7685974163401,
#             245.81905048478038,
#             261.86068598548917,
#             293.9699502330372,
#             320.98411835660943,
#             347.82758000720895,
#             376.75437315277514,
#             400.86913292003436,
#             420.98317170479913,
#             441.9657843112087,
#             462.2005918531725,
#             483.67822622728204,
#             503.3414023984258,
#             523.0752105023531,
#             539.1789587008324,
#             558.2685047128995,
#             575.6896626551852,
#             602.6470509245554,
#             606.699278642886
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             24.0,
#             140.95544858098265,
#             1222.3774480084328,
#             1872.2669937961516,
#             2421.74033374001,
#             3018.622393115824,
#             3568.894856706707,
#             4158.845094164123,
#             4842.360299398262,
#             5449.787950785592,
#             5982.447262405675,
#             6563.188892904106,
#             7147.382030343678,
#             7793.282247589865,
#             8407.840006360246,
#             9046.837483491934,
#             9584.737249914137,
#             10241.451896332697,
#             10858.783033493413,
#             11847.795387456334,
#             12000.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "Deprecjacja",
#         "zmin": null,
#         "legendgroup": "Deprecjacja",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 0, 0, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             1.92,
#             11.276435886478613,
#             97.79019584067463,
#             149.78135950369213,
#             193.7392266992008,
#             241.4897914492659,
#             285.5115885365366,
#             332.7076075331299,
#             387.388823951861,
#             435.9830360628474,
#             478.595780992454,
#             525.0551114323285,
#             571.7905624274943,
#             623.4625798071892,
#             672.6272005088197,
#             723.7469986793548,
#             766.778979993131,
#             819.3161517066158,
#             868.7026426794731,
#             947.8236309965067,
#             960.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             2500.0,
#             5000.0,
#             7500.0,
#             10000.0
#         ],
#         "range": [
#             -335.28,
#             12359.28
#         ],
#         "domain": [
#             0.09128390201224845,
#             0.9934383202099738
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0",
#             "2500",
#             "5000",
#             "7500",
#             "10000"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",

# %% [markdown]
# Wiedząc, że w stanie ustalonym $\Delta k_r= \Delta y_r=0$, stopa wzrostu produkcji "per capita" wynosi <br><br>
# $\cfrac{\Delta y}{y}=\cfrac{\Delta (y_rA)}{y_rA}=\cfrac{(\Delta y_r)A+(\Delta A)y_r}{y_rA}=\cfrac{\Delta y_r}{y_rA}+\cfrac{\Delta Ay_r}{Ay_r}=0+\cfrac{\Delta A}{A}=g$. <br><br>
#
# <b>Wniosek</b> <br>
# Zatem w stanie ustalonym tempo wzrostu kapitału i produkcji na pracownika równe jest postępowi technicznemu $g$.
